# %%
import pandas as pd 
import math
from geopy.distance import geodesic
import csv
from pandas import *
import numpy as np

df = pd.read_csv(r"C:\Users\yaoz\OneDrive - BAT\Desktop\Complete Distinct Address.csv")
df
# Out:
#                town block         street_name                      Address  \
# 0          TAMPINES   408      TAMPINES ST 41     TAMPINES ST 41 BLOCK 408
# 1          TAMPINES   410      TAMPINES ST 41     TAMPINES ST 41 BLOCK 410
# 2          TAMPINES   411      TAMPINES ST 41     TAMPINES ST 41 BLOCK 411
# 3          TAMPINES   808      TAMPINES AVE 4     TAMPINES AVE 4 BLOCK 808
# 4          TAMPINES   103      TAMPINES ST 11     TAMPINES ST 11 BLOCK 103
# ...             ...   ...                 ...                          ...
# 9399  MARINE PARADE    77           MARINE DR           MARINE DR BLOCK 77
# 9400    BUKIT TIMAH    15           TOH YI DR           TOH YI DR BLOCK 15
# 9401  MARINE PARADE    80  MARINE PARADE CTRL  MARINE PARADE CTRL BLOCK 80
# 9402  MARINE PARADE    15          MARINE TER          MARINE TER BLOCK 15
# 9403  MARINE PARADE    16          MARINE TER          MARINE TER BLOCK 16
#
#       Index  latitude   longitude
# ...

# %%
df2 = pd.read_csv(r"C:\Users\yaoz\OneDrive - BAT\Desktop\Expressway Exits.csv")
df2
# Out:
#                               Source.Name  found  totalNumPages  pageNum  \
# 0    JSON DumpPan Island Expressway1.json     85              9        1
# 1    JSON DumpPan Island Expressway1.json     85              9        1
# 2    JSON DumpPan Island Expressway1.json     85              9        1
# 3    JSON DumpPan Island Expressway1.json     85              9        1
# 4    JSON DumpPan Island Expressway1.json     85              9        1
# ..                                    ...    ...            ...      ...
# 252     JSON DumpEast Coast Parkway3.json     31              4        3
# 253     JSON DumpEast Coast Parkway3.json     31              4        3
# 254     JSON DumpEast Coast Parkway3.json     31              4        3
# 255  JSON DumpPan Island Expressway8.json     85              9        8
# 256  JSON DumpPan Island Expressway8.json     85              9        8
#
#                results.SEARCHVAL  results.BLK_NO       results.ROAD_NAME  \
# ...

# %%
### This code stores 257 Expressway exits as a JSON? Dictionary? and then for each of the 9500+ distinct addresses, computes the closest exit with the distance and exit name
import pandas as pd 
import math
from geopy.distance import geodesic

def function(latitude,longitude):
    lst = []    
    try:
        address = (latitude,longitude)
    
        for index,row in df2.iterrows():
            exit = (row['results.LATITUDE'],row['results.LONGITUDE'])
            lst.append(geodesic(address,exit).km)
    
    
        min_value = min(lst)
        min_index = lst.index(min_value) 
    
        with open('output.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([min_index, min_value]) 
            
    except ValueError:
        with open('output.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("zero")

# %%
for index, row in df.iterrows():
    i = 0
    try:
        function(row['latitude'], row['longitude']) 
    except IndexError:
        with open('output.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("error occurred")
        continue
    i+=1 
    if i % 1000 == 0:
        print(i)

# %%
df3 = pd.read_csv(r"C:\Users\yaoz\OneDrive - BAT\Desktop\mrtsg.csv")
df3
# Out:
#      OBJECTID                     STN_NAME STN_NO           X           Y  \
# 0          12        ADMIRALTY MRT STATION   NS10  24402.1063  46918.1131
# 1          16         ALJUNIED MRT STATION    EW9  33518.6049  33190.0020
# 2          33       ANG MO KIO MRT STATION   NS16  29807.2655  39105.7720
# 3          81            BAKAU LRT STATION    SE3  36026.0821  41113.8766
# 4          80          BANGKIT LRT STATION    BP9  21248.2460  40220.9693
# ..        ...                          ...    ...         ...         ...
# 184       175  WOODLANDS SOUTH MRT STATION    TE3  23607.8309  45444.7113
# 185       146        WOODLEIGH MRT STATION   NE11  32173.3186  35706.3794
# 186         6          YEW TEE MRT STATION    NS5  18438.9791  42158.0124
# 187        41     YIO CHU KANG MRT STATION   NS15  29294.1283  40413.0820
# 188        13           YISHUN MRT STATION   NS13  28187.6787  45686.0701
#
#      Latitude   Longitude   COLOR
# 0    1.440585  103.800998     RED
# ...

# %%
### This code stores finds for each 9000+ address the closest MRT Station and distance

def function_v1(latitude,longitude):
    lst = []    
    try:
        address = (latitude,longitude)
    
        for index,row in df3.iterrows():
            exit = (row['Latitude'],row['Longitude'])
            lst.append(geodesic(address,exit).km)
    
    
        min_value = min(lst)
        min_index = lst.index(min_value) 
    
        with open('mrtdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([min_index, min_value]) 
            
    except ValueError:
        with open('mrtdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("zero")



for index, row in df.iterrows():
    i = 0
    try:
        function_v1(row['latitude'], row['longitude']) 
    except IndexError:
        with open('mrtdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("error occurred")
        continue
    i+=1 
    if i % 1000 == 0:
        print(i)

# %%
df4 = pd.read_csv(r"C:\Users\yaoz\OneDrive - BAT\Desktop\primaryschoolsg.csv")
df4
# Out:
#                              Name                   Type GenderMix  \
# 0        Admiralty Primary School             Government     Mixed
# 1    Ahmad Ibrahim Primary School             Government     Mixed
# 2                  Ai Tong School  Government-aided, SAP     Mixed
# 3        Alexandra Primary School             Government     Mixed
# 4     Anchor Green Primary School             Government     Mixed
# ..                            ...                    ...       ...
# 185          Yuhua Primary School             Government     Mixed
# 186          Yumin Primary School             Government     Mixed
# 187        Zhangde Primary School             Government     Mixed
# 188       Zhenghua Primary School             Government     Mixed
# 189       Zhonghua Primary School             Government     Mixed
#
#               Area   Zone  PostalCode  Latitude  Longitude  \
# 0        Woodlands  North      738907    1.4427   103.7995
# ...

# %%
### This code stores finds for each 9000+ address the closest Primary School and distance

def function_v2(latitude,longitude):
    lst = []    
    try:
        address = (latitude,longitude)
    
        for index,row in df4.iterrows():
            exit = (row['Latitude'],row['Longitude'])
            lst.append(geodesic(address,exit).km)
    
    
        min_value = min(lst)
        min_index = lst.index(min_value) 
    
        with open('schdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([min_index, min_value]) 
            
    except ValueError:
        with open('schdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("zero")



for index, row in df.iterrows():
    i = 0
    try:
        function_v2(row['latitude'], row['longitude']) 
    except IndexError:
        with open('schdistance.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("error occurred")
        continue
    i+=1 
    if i % 1000 == 0:
        print(i)

# %%
df.to_csv('masterdata.csv')
df2.to_csv('expressway.csv')
df3.to_csv('mrt.csv')
df4.to_csv('primarysch.csv')

# %%
### This code stores finds for each 9000+ address the closest MRT Station and distance

def function_v1(latitude,longitude):
    lst = []    
    try:
        address = (latitude,longitude)
    
        for index,row in df3.iterrows():
            exit = (row['Latitude'],row['Longitude'])
            lst.append(geodesic(address,exit).km)
    
    
        min_value = min(lst)
        min_index = lst.index(min_value)
        print(df3['STN_NAME'].iloc[min_index])
    
        with open('test.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([min_index, min_value]) 
            
    except ValueError:
        with open('test.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("zero")



for index, row in df.head().iterrows():
    i = 0
    print(row['Address'])
    try:
        function_v1(row['latitude'], row['longitude']) 
    except IndexError:
        with open('test.csv', 'a', encoding='UTF8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow("error occurred")
        continue
    i+=1 
    if i % 1000 == 0:
        print(i)
# Out:
# TAMPINES ST 41 BLOCK 408
# BUKIT BATOK MRT STATION
# TAMPINES ST 41 BLOCK 410
# BUKIT BATOK MRT STATION
# TAMPINES ST 41 BLOCK 411
# BUKIT BATOK MRT STATION
# TAMPINES AVE 4 BLOCK 808
# BUKIT BATOK MRT STATION
# TAMPINES ST 11 BLOCK 103
# BUKIT BATOK MRT STATION
